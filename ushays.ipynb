# %% [markdown]
# # Ushay Reconstrucción

# %% [markdown]
# # Filtrar por sl_contract_id

# %%
import pandas as pd

# Ruta del archivo CSV
csv_path = "/workspaces/ushay_handling-2/data/dataset/2022-created_on_2024-06-04_02-05/cleaned_dataset.csv"

# Cargar el DataFrame desde el CSV
df = pd.read_csv(csv_path)

# Definir el `sl_contract_id` que quieres filtrar
sl_contract_id_filtrar = 1758481  # Cambia este ID según lo que necesites

# Filtrar el DataFrame
df_filtrado = df[df['sl_contract_id'] == sl_contract_id_filtrar]

# Verificar si hay datos
if df_filtrado.empty:
    print(f"❌ No se encontraron registros para `sl_contract_id` {sl_contract_id_filtrar}.")
else:
    print(f"✅ Se encontraron {len(df_filtrado)} registros para `sl_contract_id` {sl_contract_id_filtrar}.")
    
    # Mostrar las primeras filas
    print(df_filtrado.head())

# Guardar el resultado en un nuevo archivo CSV (opcional)
df_filtrado.to_csv(f"filtrado_{sl_contract_id_filtrar}.csv", index=False)
print(f"📂 Archivo guardado: filtrado_{sl_contract_id_filtrar}.csv")

# %%
import hashlib
import os
import pandas as pd

def calcular_hash_sha1(contenido):
    """ Calcula el hash SHA-1 del contenido proporcionado. """
    sha1 = hashlib.sha1()
    sha1.update(contenido)
    return sha1.hexdigest()

def verificar_y_guardar_archivo(unico_archivo, destino_zip):
    """ Guarda un solo archivo .ushay como ZIP sin necesidad de unir partes. """
    with open(unico_archivo, 'rb') as f:
        contenido = f.read()

    # Buscar el separador "sercop"
    separador = b'sercop'
    posicion_separador = contenido.find(separador)

    if posicion_separador == -1:
        print(f"⚠️ Advertencia: No se encontró el separador 'sercop' en {unico_archivo}.")
        return None

    # Extraer los datos reales después de "sercop"
    datos = contenido[posicion_separador + len(separador):]

    # Guardar directamente el contenido como ZIP
    with open(destino_zip, 'wb') as f:
        f.write(datos)

    print(f"✅ Archivo ZIP guardado en: {destino_zip}")
    return destino_zip

def verificar_y_unir_partes(partes, destino_zip):
    """ Une las partes de un archivo .ushay y lo guarda como un archivo ZIP binario. """
    contenido_completo = b''
    hashes_verificados = {}

    for idx, parte in enumerate(partes):
        with open(parte, 'rb') as f:
            contenido = f.read()
        
        # Separar el hash y los datos usando el separador 'sercop'
        separador = b'sercop'
        posicion_separador = contenido.find(separador)

        if posicion_separador == -1:
            print(f"⚠️ Advertencia: No se encontró el separador 'sercop' en {parte}.")
            continue

        # Extraer hashes y datos
        hashes = contenido[:posicion_separador].decode('utf-8', errors='ignore')
        datos = contenido[posicion_separador + len(separador):]

        # Extraer los hashes en formato clave-valor
        hashes_array = hashes.split(';')
        nombre_parte_actual = f"part{idx}.ushay"
        hash_esperado = None

        for hash_info in hashes_array:
            if not hash_info.strip():
                continue
            partes_hash = hash_info.split(':')
            if len(partes_hash) == 2:
                nombre_parte, hash_valor = partes_hash
                hashes_verificados[nombre_parte] = hash_valor
                if nombre_parte == nombre_parte_actual:
                    hash_esperado = hash_valor

        if hash_esperado is None:
            print(f"❌ Error: No se encontró el hash para {nombre_parte_actual} en {parte}")
            continue

        # Verificar el hash de los datos actuales
        hash_calculado = calcular_hash_sha1(datos)
        if hash_calculado != hash_esperado:
            print(f"❌ Error: Hash mismatch en {nombre_parte_actual}, esperado {hash_esperado}, calculado {hash_calculado}")
            raise Exception(f"Hash mismatch en parte: {nombre_parte_actual}")

        # Concatenar los datos
        contenido_completo += datos

    # Guardar el archivo ZIP resultante
    with open(destino_zip, 'wb') as f:
        f.write(contenido_completo)

    print(f"✅ Archivo ZIP reconstruido en: {destino_zip}")
    return destino_zip

def modificar_ruta(ruta):
    """ Reemplaza 'ushay_handling' por 'ushay_handling-2' en las rutas """
    return ruta.replace("/workspaces/ushay_handling/", "/workspaces/ushay_handling-2/")

# Ruta del dataset CSV
csv_path = "/workspaces/ushay_handling-2/data/dataset/2022-created_on_2024-06-04_02-05/cleaned_dataset.csv"

# Leer el dataset
df = pd.read_csv(csv_path)

# Filtrar solo los archivos con extensión .ushay
df = df[df['extension'] == '.ushay']

# Modificar las rutas en el DataFrame
df['file_path'] = df['file_path'].apply(modificar_ruta)

# Agrupar por sl_contract_id (cada proceso)
grupos_procesos = df.groupby('sl_contract_id')

# Definir manualmente el sl_contract_id a probar
ejemplo_contract_id = 1758631  # Reemplázalo con el ID que quieras probar

directorio_destino = "/workspaces/ushay_handling-2/notebooks/meli/"
os.makedirs(directorio_destino, exist_ok=True)

if ejemplo_contract_id in grupos_procesos.groups:
    grupo = grupos_procesos.get_group(ejemplo_contract_id)
    
    # Verificar si es un solo archivo o partes
    archivo_unico = grupo['filename'].nunique() == 1 and grupo['hash'].nunique() == 1
    
    # Ordenar los archivos
    grupo = grupo.sort_values(by='sl_descripcion_del_archivo')
    partes = grupo['file_path'].tolist()

    # Imprimir información de las rutas
    print(f"Contract ID: {ejemplo_contract_id}")
    print("Vector de rutas ordenadas:")
    for parte in partes:
        print(parte)

    # Definir el nombre del archivo ZIP
    archivo_zip = os.path.join(directorio_destino, f"{ejemplo_contract_id}.zip")

    if archivo_unico:
        # Caso 1: Solo hay un archivo (mismo nombre y hash)
        try:
            archivo_zip_completo = verificar_y_guardar_archivo(partes[0], archivo_zip)
            if archivo_zip_completo:
                print(f"✅ Archivo ZIP guardado en: {archivo_zip_completo}")
        except Exception as e:
            print(f"❌ Error en proceso {ejemplo_contract_id}: {e}")
    else:
        # Caso 2: Hay múltiples partes, unirlas
        try:
            archivo_zip_completo = verificar_y_unir_partes(partes, archivo_zip)
            print(f"✅ Archivo ZIP reconstruido en: {archivo_zip_completo}")
        except Exception as e:
            print(f"❌ Error en proceso {ejemplo_contract_id}: {e}") 
else:
    print(f"❌ Error: No se encontró el sl_contract_id {ejemplo_contract_id} en el dataset.")

# %%
import pandas as pd

# Ruta del dataset CSV (ajusta si es necesario)
csv_path = "/workspaces/ushay_handling/data/dataset/2022-created_on_2024-06-04_02-05/cleaned_dataset.csv"

# Cargar el dataset
df = pd.read_csv(csv_path)

# Cantidad total de registros en el dataset
print(f"📊 Total de registros en el dataset: {len(df)}")

# Filtrar solo los archivos con extensión .ushay
df_ushay = df[df['extension'] == '.ushay']

# Cantidad de archivos con extensión .ushay
print(f"📂 Archivos con extensión .ushay: {len(df_ushay)}")

# Contar la cantidad de procesos únicos (sl_contract_id)
num_procesos = df_ushay['sl_contract_id'].nunique()
print(f"🔹 Procesos únicos con archivos .ushay: {num_procesos}")

# Mostrar algunas filas para ver qué datos están apareciendo
print("\n🔍 Ejemplo de datos filtrados:")
print(df_ushay[['sl_contract_id', 'sl_descripcion_del_archivo', 'file_path']].head(10))
# Out:
# 📊 Total de registros en el dataset: 14342
# 📂 Archivos con extensión .ushay: 4811
# 🔹 Procesos únicos con archivos .ushay: 3685
#
# 🔍 Ejemplo de datos filtrados:
#     sl_contract_id        sl_descripcion_del_archivo  \
# 2          1724739                       part1.ushay
# 3          1724739                       part2.ushay
# 4          1724739                       part0.ushay
# 6          1757431     contratacion_pli_subinv.ushay
# 9          1755652     contratacion_pli_subinv.ushay
# 16         1755018     contratacion_pli_subinv.ushay
# 21         1747349  contratacion_pli_subinv(4).ushay
# 22         1746667     contratacion_pli_subinv.ushay
# 27         1746522     contratacion_pli_subinv.ushay
# 29         1746358  contratacion_pli_subinv(1).ushay
#
#                                             file_path
# 2   /workspaces/ushay_handling/data/dataset/2022-c...
# 3   /workspaces/ushay_handling/data/dataset/2022-c...
# 4   /workspaces/ushay_handling/data/dataset/2022-c...
# 6   /workspaces/ushay_handling/data/dataset/2022-c...
# 9   /workspaces/ushay_handling/data/dataset/2022-c...
# 16  /workspaces/ushay_handling/data/dataset/2022-c...
# 21  /workspaces/ushay_handling/data/dataset/2022-c...
# 22  /workspaces/ushay_handling/data/dataset/2022-c...
# 27  /workspaces/ushay_handling/data/dataset/2022-c...
# 29  /workspaces/ushay_handling/data/dataset/2022-c...

# %% [markdown]
# # Código Mejorado para Procesar Todos los <sl_contract_id>

# %%
import hashlib
import os
import pandas as pd

def calcular_hash_sha1(contenido):
    """ Calcula el hash SHA-1 del contenido proporcionado. """
    sha1 = hashlib.sha1()
    sha1.update(contenido)
    return sha1.hexdigest()

def verificar_y_guardar_archivo(unico_archivo, destino_zip):
    """ Guarda un solo archivo .ushay como ZIP sin necesidad de unir partes. """
    with open(unico_archivo, 'rb') as f:
        contenido = f.read()

    # Buscar el separador "sercop"
    separador = b'sercop'
    posicion_separador = contenido.find(separador)

    if posicion_separador == -1:
        print(f"⚠️ Advertencia: No se encontró el separador 'sercop' en {unico_archivo}.")
        return None

    # Extraer los datos reales después de "sercop"
    datos = contenido[posicion_separador + len(separador):]

    # Guardar directamente el contenido como ZIP
    with open(destino_zip, 'wb') as f:
        f.write(datos)

    print(f"✅ Archivo ZIP guardado en: {destino_zip}")
    return destino_zip

def verificar_y_unir_partes(partes, destino_zip):
    """ Une las partes de un archivo .ushay y lo guarda como un archivo ZIP binario. """
    contenido_completo = b''

    for idx, parte in enumerate(partes):
        with open(parte, 'rb') as f:
            contenido = f.read()
        
        # Separar el hash y los datos usando el separador 'sercop'
        separador = b'sercop'
        posicion_separador = contenido.find(separador)

        if posicion_separador == -1:
            print(f"⚠️ Advertencia: No se encontró el separador 'sercop' en {parte}.")
            continue

        # Extraer los datos reales después de "sercop"
        datos = contenido[posicion_separador + len(separador):]

        # Concatenar los datos
        contenido_completo += datos

    # Guardar el archivo ZIP resultante
    with open(destino_zip, 'wb') as f:
        f.write(contenido_completo)

    print(f"✅ Archivo ZIP reconstruido en: {destino_zip}")
    return destino_zip

def modificar_ruta(ruta):
    """ Reemplaza 'ushay_handling' por 'ushay_handling-2' en las rutas """
    return ruta.replace("/workspaces/ushay_handling/", "/workspaces/ushay_handling-2/")

# 📂 **Ruta del dataset CSV**
csv_path = "/workspaces/ushay_handling-2/data/dataset/2022-created_on_2024-06-04_02-05/cleaned_dataset.csv"

# 📌 **Leer el dataset**
df = pd.read_csv(csv_path)

# 🔹 **Filtrar solo los archivos con extensión .ushay**
df = df[df['extension'] == '.ushay']

# 🔄 **Modificar las rutas en el DataFrame**
df['file_path'] = df['file_path'].apply(modificar_ruta)

# 📌 **Obtener todos los `sl_contract_id` únicos**
sl_contract_ids = df['sl_contract_id'].unique()

# 📂 **Directorio donde se guardarán los ZIPs**
directorio_destino = "/workspaces/ushay_handling-2/notebooks/meli/"
os.makedirs(directorio_destino, exist_ok=True)

# 🔥 **Procesar todos los `sl_contract_id` únicos**
for contract_id in sl_contract_ids:
    grupo = df[df['sl_contract_id'] == contract_id]
    
    # Verificar si es un solo archivo o partes
    archivo_unico = grupo['filename'].nunique() == 1 and grupo['hash'].nunique() == 1

    # Ordenar los archivos
    grupo = grupo.sort_values(by='sl_descripcion_del_archivo')
    partes = grupo['file_path'].tolist()

    # 📌 **Definir el nombre del archivo ZIP**
    archivo_zip = os.path.join(directorio_destino, f"{contract_id}.zip")

    if archivo_unico:
        # ✅ **Caso 1: Solo hay un archivo (mismo nombre y hash)**
        try:
            archivo_zip_completo = verificar_y_guardar_archivo(partes[0], archivo_zip)
            if archivo_zip_completo:
                print(f"✅ Archivo ZIP guardado en: {archivo_zip_completo}")
        except Exception as e:
            print(f"❌ Error en contrato {contract_id}: {e}")
    else:
        # ✅ **Caso 2: Hay múltiples partes, unirlas**
        try:
            archivo_zip_completo = verificar_y_unir_partes(partes, archivo_zip)
            print(f"✅ Archivo ZIP reconstruido en: {archivo_zip_completo}")
        except Exception as e:
            print(f"❌ Error en contrato {contract_id}: {e}")

print("🎯 **Procesamiento completado para todos los sl_contract_id únicos!**")

# %% [markdown]
# # Descomprimir .zips

# %%
import os
import zipfile

def descomprimir_archivos_zip(directorio_zip, directorio_destino):
    """Descomprime todos los archivos .zip en un directorio de salida sin crear carpetas innecesarias."""

    # Obtener la lista de archivos .zip en el directorio
    archivos_zip = [f for f in os.listdir(directorio_zip) if f.endswith('.zip')]

    if not archivos_zip:
        print("❌ No se encontraron archivos ZIP en el directorio.")
        return

    for archivo in archivos_zip:
        ruta_zip = os.path.join(directorio_zip, archivo)
        nombre_carpeta = os.path.splitext(archivo)[0]  # Nombre del ZIP sin la extensión
        ruta_destino = os.path.join(directorio_destino, nombre_carpeta)

        try:
            with zipfile.ZipFile(ruta_zip, 'r') as zip_ref:
                # Verificar si el archivo ZIP es válido antes de extraerlo
                if zip_ref.testzip() is not None:
                    print(f"❌ Error: {ruta_zip} está corrupto y no puede ser descomprimido.")
                    continue  # Salta este archivo corrupto

                # Solo crear la carpeta si el archivo ZIP es válido
                os.makedirs(ruta_destino, exist_ok=True)
                zip_ref.extractall(ruta_destino)
                print(f"✅ Archivo descomprimido: {ruta_zip} en {ruta_destino}")

        except zipfile.BadZipFile:
            print(f"❌ Error: {ruta_zip} no es un archivo ZIP válido.")

# Directorios de trabajo
directorio_zip = "/Users/melisaguerrero/Desktop/kapak/meli/"
directorio_destino = "/Users/melisaguerrero/Desktop/kapak/unzip/"

descomprimir_archivos_zip(directorio_zip, directorio_destino)
# Out:
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1692435.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1692435
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1728817.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1728817
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1756305.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1756305
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1709615.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1754506.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1754506
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1712553.zip no es un archivo ZIP válido.
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1693059.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1752611.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1752611
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1749557.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1749557
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1717365.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1717365
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1698124.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1698124
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1751456.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1751456
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1758300.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1710378.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1710378
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1758466.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1712209.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1712209
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1715566.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1715566
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1729512.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1736432.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1736432
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1712584.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1712584
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1741876.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1741876
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1757972.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1757972
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1698681.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1698681
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1741686.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1741686
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1714863.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1714863
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1682815.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1682815
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1696860.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1696860
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1727926.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1727926
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1722686.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1722686
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1694520.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1694520
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1744503.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1744503
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1719162.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1719162
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1744271.zip no es un archivo ZIP válido.
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1683048.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1708721.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1708721
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1698440.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1698440
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1717167.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1717167
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1682418.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1690008.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1690008
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1698454.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1698454
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1691470.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1691470
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1703853.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1703853
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1712786.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1736630.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1736630
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1734755.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1734755
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1729062.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1729062
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1745812.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1745812
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1737512.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1737512
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1679669.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1679669
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1725116.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1725116
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1742827.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1742827
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1734769.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1723573.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1723573
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1678563.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1678563
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1690632.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1690632
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1706644.zip no es un archivo ZIP válido.
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1716457.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1708669.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1708669
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1685559.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1685559
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1744311.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1714526.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1714526
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1696525.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1696525
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1701659.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1721589.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1721589
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1706136.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1706136
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1692031.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1692031
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1742012.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1742012
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1706888.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1706888
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1752229.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1752229
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1697161.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1713275.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1713275
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1729857.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1729857
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1691504.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1691504
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1679912.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1679912
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1729664.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1729664
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1739305.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1739305
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1717946.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1717946
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1722725.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1722725
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1735259.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1735259
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1731017.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1731017
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1755585.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1733600.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1733600
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1753692.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1753692
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1688096.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1680145.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1680145
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1751278.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1751278
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1689161.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1689161
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1719566.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1719566
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1737843.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1737843
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1749345.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1746076.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1746076
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1706334.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1706334
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1746738.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1682008.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1682008
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1703502.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1751536.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1751536
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1685015.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1685015
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1739113.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1739113
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1739661.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1739661
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1731573.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1731573
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1724618.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1724618
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1733402.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1733402
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1702807.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1702807
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1691909.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1691909
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1720318.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1721012.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1721012
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1750833.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1750833
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1
zip en /Users/melisaguerrero/Desktop/kapak/unzip/1699790
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1730502.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1730502
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1750590.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1750590
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1721369.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1681685.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1681685
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1706926.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1706926
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1682373.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1682373
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1744532.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1744532
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1727917.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1727917
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1686115.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1686115
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1693518.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1693518
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1752422.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1752422
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1710611.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1710611
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1686101.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1686101
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1714311.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1714311
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1708710.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1715741.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1715741
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1683737.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1683737
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1742619.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1742619
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1755365.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1691333.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1691333
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1707345.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1707345
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1741310.zip no es un archivo ZIP válido.
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1709368.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1720922.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1720922
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1748452.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1748452
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1711533.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1711533
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1720936.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1705977.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1705977
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1742382.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1742382
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1694908.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1694908
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1755826.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1755826
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1750792.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1750792
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1756485.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1714846.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1714846
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1738374.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1738374
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1694920.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1694920
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1744903.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1737053.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1737053
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1721631.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1721631
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1739095.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1739095
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1757994.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1757994
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1696104.zip no es un archivo ZIP válido.
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1723973.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1756320.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1756320
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1757770.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1757770
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1717354.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1717354
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1703321.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1703321
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1743705.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1743705
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1753270.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1753270
# ❌ Error: /Users/melisaguerrero/Desktop/kapak/meli/1691643.zip no es un archivo ZIP válido.
# ✅ Archivo descomprimido: /Users/melisaguerrero/Desktop/kapak/meli/1717340.zip en /Users/melisaguerrero/Desktop/kapak/unzip/1717340

# %% [markdown]
# # Realizar embeddings

# %%
import sys
import scipy
import gensim

print("Python Version:", sys.version)
print("SciPy Version:", scipy.__version__)
print("Gensim Version:", gensim.__version__)
# Out:
# Python Version: 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 10:14:12) [Clang 14.0.6 ]
# SciPy Version: 1.11.4
# Gensim Version: 4.3.2

# %%
import os
import gensim
import pdfplumber
from docx import Document
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import pandas as pd

# Ruta donde están los archivos descomprimidos
directorio_documentos = "/Users/melisaguerrero/Desktop/kapak/unzip"

# Archivos y extensiones a excluir
archivos_excluir = {"proceso.xml", "zip.info"}
extensiones_excluir = {".jpg", ".jpeg", ".png", ".gif", ".bmp", ".tiff", ".zip", ".rar", ".tar", ".gz", ".mp4", ".mp3"}

def extraer_texto_pdf(ruta_pdf):
    """Extrae el texto de un archivo PDF."""
    texto = ""
    try:
        with pdfplumber.open(ruta_pdf) as pdf:
            for pagina in pdf.pages:
                texto += pagina.extract_text() + "\n"
    except Exception as e:
        print(f"⚠️ No se pudo extraer texto de {ruta_pdf}: {e}")
    return texto.strip()

def extraer_texto_docx(ruta_docx):
    """Extrae el texto de un archivo DOCX."""
    texto = ""
    try:
        doc = Document(ruta_docx)
        for parrafo in doc.paragraphs:
            texto += parrafo.text + "\n"
    except Exception as e:
        print(f"⚠️ No se pudo extraer texto de {ruta_docx}: {e}")
    return texto.strip()

# Leer archivos dentro de los subdirectorios
documentos = []
for carpeta in os.listdir(directorio_documentos):
    ruta_carpeta = os.path.join(directorio_documentos, carpeta)

    if not os.path.isdir(ruta_carpeta):
        continue  # Omitir archivos sueltos en el directorio principal

    for archivo in os.listdir(ruta_carpeta):
        ruta_archivo = os.path.join(ruta_carpeta, archivo)

        if archivo in archivos_excluir or any(archivo.lower().endswith(ext) for ext in extensiones_excluir):
            print(f"⚠️ Archivo omitido por ser binario: {ruta_archivo}")
            continue  

        contenido = ""
        try:
            if archivo.lower().endswith(".txt"):
                with open(ruta_archivo, "r", encoding="utf-8") as f:
                    contenido = f.read()
            elif archivo.lower().endswith(".pdf"):
                contenido = extraer_texto_pdf(ruta_archivo)
            elif archivo.lower().endswith(".docx"):
                contenido = extraer_texto_docx(ruta_archivo)
            else:
                print(f"⚠️ Tipo de archivo no soportado: {ruta_archivo}")
                continue  

            if contenido.strip():  # Solo agregar documentos con contenido
                documentos.append(TaggedDocument(words=contenido.split(), tags=[f"{carpeta}/{archivo}"]))

        except Exception as e:
            print(f"⚠️ Error al procesar {ruta_archivo}: {e}")

# Entrenar modelo Doc2Vec solo si hay documentos válidos
if documentos:
    modelo_doc2vec = Doc2Vec(vector_size=100, window=5, min_count=2, workers=4, epochs=10)
    modelo_doc2vec.build_vocab(documentos)
    modelo_doc2vec.train(documentos, total_examples=modelo_doc2vec.corpus_count, epochs=modelo_doc2vec.epochs)

    #  Guardar el modelo entrenado
    modelo_doc2vec.save("modelo_doc2vec")

    # Generar embeddings para cada documento
    embeddings = {doc.tags[0]: modelo_doc2vec.infer_vector(doc.words) for doc in documentos}

    #  Convertir embeddings en un DataFrame
    df_embeddings = pd.DataFrame.from_dict(embeddings, orient='index')

    #  Guardar embeddings en un CSV
    df_embeddings.to_csv("embeddings.csv")

    print("Embeddings generados y guardados en 'embeddings.csv'")
else:
    print("No se encontraron documentos de texto para procesar.")
# Out:
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1697305/proceso.xml
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1697305/8-Anexo 01-Terminos de Referencia-signed-WORD.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1697305/LOGO-MSP.jpg
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1697305/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1679227/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1679227/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1718396/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1718396/logo2021.jpg
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1718396/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1726499/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1726499/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1726499/logo_MSP_2022.jpg
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1726499/11-FORMULARIOS ADICIONALES DE LA OFERTA SIE.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1707970/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1707970/zip.info
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1707970/5-FORMULARIO 1 1 Y 1 3.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1744019/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1744019/LOGO 2018.jpg
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1744019/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1732409/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1732409/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1732409/LOGO HCAM.jpg
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1757431/22-CONDICIONES GENERALES DE CONTRATO SIE.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1757431/22-FORMULARIO DE COMPROMISO ASOCIACION O CONSORCIO SIE.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1757431/proceso.xml
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1757431/22-CONDICIONES PARTICULARES CONTRATO SIE.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1757431/22-INDICE SIE.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1757431/22-CONDICIONES GENERALES PLIEGOS SIE.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1757431/zip.info
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1757431/22-FORMULARIO DE OFERTA SIE.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1732294/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1732294/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1732294/logo.jpg
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1720751/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1720751/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1720751/Logo para USHAY.jpg
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1714564/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1714564/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1714564/LOGO BOMBEROS.jpg
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1751190/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1751190/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1751190/LOGO.jpg
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1700732/7-3_formulario_de_compromiso_de_asociacion_o_consorcio.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1700732/7-5_condiciones_generales_del_contrato_de_subasta_inversa_electronica_bienes_y_servicios.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1700732/proceso.xml
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1700732/7-condiciones_particulares_del_contrato_de_subasta_inversa_electronica.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1700732/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1700732/LOGO2.jpg
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1700732/7-INF_ADQ_TUBO_FLOTADOR.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1700732/7-FORMULARIOS DE LA OFERTA RESOL 124.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1727322/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1727322/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1732436/proceso.xml
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1732436/27-0_indice_de_subasta_inversa_electronica.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1732436/27-condiciones_particulares_del_contrato_de_subasta_inversa_electronica-1.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1732436/27-5 Formularios de la oferta actualizados.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1732436/27-5_condiciones_generales_del_contrato_de_subasta_inversa_electronica_bienes_y_servicios.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1732436/zip.info
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1732436/27-1_condiciones_particulares_del_pliego_de_subasta_inversa_electronica1.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1732436/27-3_formulario_de_compromiso_de_asociacion_o_consorcio no cambia.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1700190/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1700190/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1700190/Logo GAD Yacuambi.jpg
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1719881/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1719881/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1751500/proceso.xml
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1751500/40-1-4_condiciones_particulares_del_contrato_de_subasta_inversa_electronica.doc
# ⚠️ Tipo de archivo no soportado: /Users/melisaguerrero/Desktop/kapak/unzip/1751500/40-5_condiciones_generales_del_contrato_de_subasta_inversa_electronica_bienes_y_servicios OK.doc
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1751500/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1751500/LOGO GADPP.jpg
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1721825/proceso.xml
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1721825/zip.info
# ⚠️ Archivo omitido por ser binario: /Users/melisaguerrero/Desktop/kapak/unzip/1